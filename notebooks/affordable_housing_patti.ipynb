# %% [markdown]
# # Affordable Housing

# %% [markdown]
# Question 1)
#
# --Which areas of Davidson County have seen the most rapid increase in home prices?
#
# --Which ones are losing affordable housing?
#
# You can choose different ways to slice the data - by council district or by zipcode, for example.

# %%
#Use Postgres database using squalchemy library, within python notebook. 
from sqlalchemy import create_engine

# %% [markdown]
# First, create a connection string. The format is
#
#  ```<dialect(+driver)>://<username>:<password>@<hostname>:<port>/<database>```

# %%
connection_string = "postgres://postgres:postgres@localhost:5432/parcels"

# %%
#create an engine and use it to connect
engine = create_engine(connection_string)

# %% [markdown]
# 1a:  First look at the average home price per day/per zip code from 1/1/2010 to 4/30/2021

# %%
#create query and pass it into the .query() method EXTRACT (YEAR FROM birth_date) AS YEAR,
Q1a = '''
SELECT EXTRACT (YEAR FROM owndate) AS year, saleprice, council, propzip, ludesc, taxdist
from property_updated
WHERE 
owndate >= '2010-01-01' AND
owndate <= '2021-04-30' AND
council >= '1' AND 
council <= '35' AND 
ludesc in (
    'DUPLEX',
    'QUADPLEX',
    'RESIDENTIAL CONDO',
    'SINGLE FAMILY',
    'TRIPLEX',
    'ZERO LOT LINE',
    'VACANT RESIDENTIAL LAND')
GROUP BY owndate, saleprice, propzip, ludesc, council, taxdist
ORDER BY owndate, saleprice;
'''

result = engine.execute(Q1a)

# ROUND(AVG(saleprice)) AS ave_price,

# %% [markdown]
# Fetch the results as tuples using either `fetchone` or `fetchall`:

# %%
result.fetchone()
# Out:
# (2010.0, Decimal('0.0'), 21, 37209, 'SINGLE FAMILY', 'USD')

# %%
result.fetchall()
# Out:
# [(2010.0, Decimal('395500.0'), 21, 37203, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('0.0'), 26, 37211, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 5, 37207, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('86825.0'), 9, 37115, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('103000.0'), 20, 37209, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('115000.0'), 8, 37115, 'SINGLE FAMILY', 'USD '),
#  (2010.0, Decimal('155000.0'), 27, 37211, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('310000.0'), 23, 37205, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('387185.0'), 19, 37203, 'RESIDENTIAL CONDO', 'GBID'),
#  (2010.0, Decimal('0.0'), 6, 37206, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 13, 37214, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('0.0'), 12, 37076, 'RESIDENTIAL CONDO', 'GSD'),
#  (2010.0, Decimal('107000.0'), 9, 37115, 'SINGLE FAMILY', 'USD '),
#  (2010.0, Decimal('160000.0'), 23, 37205, 'ZERO LOT LINE', 'USD'),
#  (2010.0, Decimal('160000.0'), 33, 37013, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('965000.0'), 23, 37205, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('1900000.0'), 34, 37215, 'SINGLE FAMILY', 'FH'),
#  (2010.0, Decimal('0.0'), 13, 37217, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 28, 37013, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 25, 37215, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 33, 37013, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('68250.0'), 3, 37207, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('76900.0'), 20, 37209, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('126549.0'), 15, 37214, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('274000.0'), 34, 37221, 'RESIDENTIAL CONDO', 'GSD'),
#  (2010.0, Decimal('315000.0'), 26, 37220, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('357000.0'), 19, 37203, 'RESIDENTIAL CONDO', 'GBID'),
#  (2010.0, Decimal('0.0'), 23, 37205, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 15, 37214, 'DUPLEX', 'USD'),
#  (2010.0, Decimal('78900.0'), 27, 37013, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('88000.0'), 31, 37211, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('123000.0'), 22, 37221, 'RESIDENTIAL CONDO', 'GSD'),
#  (2010.0, Decimal('352000.0'), 19, 37203, 'RESIDENTIAL CONDO', 'GBID'),
#  (2010.0, Decimal('1402500.0'), 14, 37076, 'VACANT RESIDENTIAL LAND', 'GSD'),
#  (2010.0, None, 14, 37076, 'VACANT RESIDENTIAL LAND', 'GSD'),
#  (2010.0, Decimal('0.0'), 27, 37211, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 25, 37215, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('79000.0'), 11, 37138, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('90000.0'), 19, 37212, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('110000.0'), 17, 37204, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('116000.0'), 1, 37189, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('128300.0'), 4, 37027, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('128500.0'), 27, 37211, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('143000.0'), 28, 37013, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('185600.0'), 4, 37211, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('212561.0'), 31, 37013, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('224000.0'), 24, 37209, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('412500.0'), 21, 37203, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('1310000.0'), 34, 37215, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 24, 37209, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 17, 37212, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('33000.0'), 29, 37013, 'ZERO LOT LINE', 'USD'),
#  (2010.0, Decimal('99000.0'), 16, 37211, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('112900.0'), 9, 37115, 'SINGLE FAMILY', 'USD '),
#  (2010.0, Decimal('112900.0'), 9, 37115, 'VACANT RESIDENTIAL LAND', 'USD '),
#  (2010.0, Decimal('141130.0'), 22, 37221, 'RESIDENTIAL CONDO', 'GSD'),
#  (2010.0, Decimal('179900.0'), 25, 37215, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('259000.0'), 24, 37205, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('1435000.0'), 34, 37215, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 22, 37221, 'RESIDENTIAL CONDO', 'GSD'),
#  (2010.0, Decimal('0.0'), 7, 37216, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 32, 37013, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('0.0'), 1, 37218, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 1, 37218, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('2445.0'), 21, 37208, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('12000.0'), 21, 37208, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('125000.0'), 8, 37115, 'SINGLE FAMILY', 'USD '),
#  (2010.0, Decimal('129900.0'), 15, 37214, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('139000.0'), 31, 37211, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('0.0'), 34, 37220, 'SINGLE FAMILY', 'OH'),
#  (2010.0, Decimal('0.0'), 11, 37138, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('0.0'), 25, 37215, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 4, 37211, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('0.0'), 7, 37206, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 28, 37013, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 33, 37013, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('185000.0'), 22, 37221, 'DUPLEX', 'GSD'),
#  (2010.0, Decimal('395000.0'), 4, 37027, 'SINGLE FAMILY', 'USD'),
#  (2010.0, None, 20, 37209, 'VACANT RESIDENTIAL LAND', 'USD'),
#  (2010.0, Decimal('0.0'), 19, 37203, 'RESIDENTIAL CONDO', 'GBID'),
#  (2010.0, Decimal('0.0'), 15, 37214, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 17, 37203, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('71000.0'), 17, 37210, 'DUPLEX', 'USD'),
#  (2010.0, Decimal('108000.0'), 30, 37211, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('153200.0'), 33, 37013, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('160200.0'), 27, 37211, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('412500.0'), 21, 37203, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, None, 13, 37217, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 2, 37218, 'VACANT RESIDENTIAL LAND', 'USD'),
#  (2010.0, Decimal('0.0'), 10, 37072, 'SINGLE FAMILY', 'GO'),
#  (2010.0, Decimal('0.0'), 23, 37205, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('0.0'), 32, 37013, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 1, 37080, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('10000.0'), 26, 37211, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('24500.0'), 19, 37208, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('88900.0'), 2, 37207, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('113000.0'), 3, 37218, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('121900.0'), 15, 37210, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('142250.0'), 32, 37013, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('145000.0'), 1, 37080, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('159900.0'), 19, 37203, 'RESIDENTIAL CONDO', 'CBID'),
#  (2010.0, Decimal('194500.0'), 14, 37214, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('232500.0'), 24, 37209, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('259792.0'), 19, 37201, 'RESIDENTIAL CONDO', 'CBID'),
#  (2010.0, Decimal('346500.0'), 21, 37203, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('370000.0'), 20, 37209, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('661225.0'), 24, 37215, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('61501.0'), 3, 37207, 'DUPLEX', 'USD '),
#  (2010.0, Decimal('120000.0'), 1, 37218, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 30, 37013, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 16, 37211, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 34, 37220, 'SINGLE FAMILY', 'OH'),
#  (2010.0, Decimal('23682.0'), 3, 37207, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('57000.0'), 13, 37214, 'ZERO LOT LINE', 'GSD'),
#  (2010.0, Decimal('62500.0'), 35, 37221, 'RESIDENTIAL CONDO', 'GSD'),
#  (2010.0, Decimal('80323.0'), 10, 37072, 'SINGLE FAMILY', 'GO'),
#  (2010.0, Decimal('144000.0'), 3, 37207, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('163900.0'), 13, 37217, 'DUPLEX', 'USD'),
#  (2010.0, Decimal('199900.0'), 31, 37013, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('328289.0'), 35, 37221, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('825000.0'), 34, 37220, 'SINGLE FAMILY', 'OH'),
#  (2010.0, Decimal('0.0'), 35, 37221, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('412.0'), 20, 37209, 'VACANT RESIDENTIAL LAND', 'USD'),
#  (2010.0, Decimal('432.0'), 29, 37217, 'VACANT RESIDENTIAL LAND', 'USD'),
#  (2010.0, Decimal('474.0'), 2, 37207, 'VACANT RESIDENTIAL LAND', 'USD'),
#  (2010.0, Decimal('486.0'), 19, 37210, 'VACANT RESIDENTIAL LAND', 'USD'),
#  (2010.0, Decimal('532.0'), 21, 37208, 'VACANT RESIDENTIAL LAND', 'USD'),
#  (2010.0, Decimal('541.0'), 5, 37206, 'VACANT RESIDENTIAL LAND', 'USD'),
#  (2010.0, Decimal('1153.0'), 5, 37206, 'VACANT RESIDENTIAL LAND', 'USD'),
#  (2010.0, Decimal('10000.0'), 35, 37221, 'VACANT RESIDENTIAL LAND', 'GSD'),
#  (2010.0, Decimal('36500.0'), 28, 37013, 'ZERO LOT LINE', 'USD'),
#  (2010.0, Decimal('89900.0'), 13, 37214, 'ZERO LOT LINE', 'GSD'),
#  (2010.0, Decimal('146500.0'), 33, 37013, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('148300.0'), 33, 37135, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('189900.0'), 33, 37135, 'ZERO LOT LINE', 'GSD'),
#  (2010.0, Decimal('205000.0'), 33, 37013, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('221500.0'), 25, 37204, 'ZERO LOT LINE', 'USD'),
#  (2010.0, Decimal('0.0'), 4, 37211, 'DUPLEX', 'GSD'),
#  (2010.0, Decimal('0.0'), 6, 37206, 'DUPLEX', 'USD'),
#  (2010.0, Decimal('21000.0'), 29, 37217, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('55000.0'), 9, 37115, 'SINGLE FAMILY', 'USD '),
#  (2010.0, Decimal('58000.0'), 9, 37115, 'SINGLE FAMILY', 'USD '),
#  (2010.0, Decimal('73501.0'), 15, 37214, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('86600.0'), 32, 37013, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('117500.0'), 32, 37013, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('131000.0'), 29, 37013, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('149900.0'), 33, 37013, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('239435.0'), 35, 37221, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, None, 32, 37013, 'VACANT RESIDENTIAL LAND', 'USD'),
#  (2010.0, Decimal('0.0'), 27, 37211, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('8916.0'), 13, 37214, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('87900.0'), 8, 37207, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('112000.0'), 16, 37211, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('174510.0'), 3, 37189, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal
7, 37216, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 34, 37220, 'VACANT RESIDENTIAL LAND', 'OH'),
#  (2010.0, Decimal('0.0'), 31, 37013, 'VACANT RESIDENTIAL LAND', 'GSD'),
#  (2010.0, Decimal('35000.0'), 26, 37211, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('41000.0'), 13, 37214, 'RESIDENTIAL CONDO', 'GSD'),
#  (2010.0, Decimal('67000.0'), 7, 37216, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('75000.0'), 2, 37207, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('112221.0'), 29, 37013, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('182500.0'), 32, 37013, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('247000.0'), 24, 37205, 'TRIPLEX', 'USD'),
#  (2010.0, Decimal('265000.0'), 4, 37027, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('335000.0'), 23, 37205, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('340000.0'), 23, 37205, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('366000.0'), 6, 37206, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('726000.0'), 24, 37205, 'SINGLE FAMILY', 'USD'),
#  (2010.0, None, 25, 37215, 'VACANT RESIDENTIAL LAND', 'USD'),
#  (2010.0, Decimal('0.0'), 13, 37214, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('0.0'), 13, 37217, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 31, 37013, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('0.0'), 10, 37072, 'SINGLE FAMILY', 'GO'),
#  (2010.0, Decimal('28000.0'), 2, 37207, 'DUPLEX', 'USD'),
#  (2010.0, Decimal('66000.0'), 13, 37217, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('85950.0'), 13, 37214, 'ZERO LOT LINE', 'GSD'),
#  (2010.0, Decimal('116500.0'), 33, 37013, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('164500.0'), 13, 37214, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('0.0'), 22, 37221, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('0.0'), 13, 37214, 'VACANT RESIDENTIAL LAND', 'GSD'),
#  (2010.0, Decimal('0.0'), 11, 37138, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('73000.0'), 31, 37013, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('85000.0'), 8, 37115, 'DUPLEX', 'USD '),
#  (2010.0, Decimal('91000.0'), 16, 37210, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('115000.0'), 9, 37115, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('119500.0'), 2, 37218, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('130000.0'), 5, 37206, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('135000.0'), 13, 37217, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('170000.0'), 35, 37221, 'RESIDENTIAL CONDO', 'GSD'),
#  (2010.0, Decimal('174710.0'), 3, 37189, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('179900.0'), 12, 37076, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('200500.0'), 11, 37138, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('275000.0'), 15, 37214, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('950000.0'), 34, 37215, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('3200000.0'), 19, 37203, 'VACANT RESIDENTIAL LAND', 'USD'),
#  (2010.0, Decimal('0.0'), 21, 37208, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 28, 37013, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('53633.0'), 28, 37013, 'ZERO LOT LINE', 'USD'),
#  (2010.0, Decimal('60000.0'), 2, 37208, 'ZERO LOT LINE', 'USD'),
#  (2010.0, Decimal('85000.0'), 21, 37209, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('85000.0'), 16, 37217, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('106000.0'), 4, 37027, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('115000.0'), 17, 37210, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('116955.0'), 5, 37206, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('118500.0'), 29, 37217, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('120000.0'), 16, 37217, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('134900.0'), 11, 37076, 'RESIDENTIAL CONDO', 'GSD'),
#  (2010.0, Decimal('139900.0'), 34, 37215, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('145000.0'), 9, 37115, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('150000.0'), 31, 37211, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('152785.0'), 14, 37076, 'RESIDENTIAL CONDO', 'GSD'),
#  (2010.0, Decimal('154900.0'), 33, 37013, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('155000.0'), 15, 37214, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('157500.0'), 1, 37080, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('158000.0'), 29, 37217, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('159000.0'), 11, 37076, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('174000.0'), 22, 37221, 'ZERO LOT LINE', 'GSD'),
#  (2010.0, Decimal('204990.0'), 22, 37221, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('208600.0'), 31, 37013, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('215000.0'), 22, 37221, 'RESIDENTIAL CONDO', 'GSD'),
#  (2010.0, Decimal('218000.0'), 12, 37076, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('225000.0'), 26, 37211, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('228000.0'), 35, 37221, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('243000.0'), 35, 37221, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('245000.0'), 24, 37209, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('259000.0'), 35, 37221, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('270000.0'), 19, 37212, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('275000.0'), 35, 37221, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('279900.0'), 4, 37027, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('284500.0'), 20, 37209, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('289000.0'), 19, 37203, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('307474.0'), 14, 37076, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('345000.0'), 4, 37027, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('387000.0'), 35, 37221, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('443700.0'), 9, 37115, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('482000.0'), 34, 37215, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('812500.0'), 34, 37220, 'SINGLE FAMILY', 'OH'),
#  (2010.0, Decimal('1100000.0'), 25, 37215, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 2, 37207, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 35, 37221, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('375000.0'), 19, 37203, 'RESIDENTIAL CONDO', 'GBID'),
#  (2010.0, Decimal('0.0'), 23, 37205, 'SINGLE FAMILY', 'BM'),
#  (2010.0, Decimal('34755.0'), 10, 37115, 'ZERO LOT LINE', 'GSD'),
#  (2010.0, Decimal('75000.0'), 3, 37207, 'DUPLEX', 'USD '),
#  (2010.0, Decimal('106900.0'), 8, 37115, 'SINGLE FAMILY', 'USD '),
#  (2010.0, Decimal('120000.0'), 8, 37115, 'RESIDENTIAL CONDO', 'USD '),
#  (2010.0, Decimal('127000.0'), 35, 37221, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('127500.0'), 25, 37215, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('208000.0'), 18, 37212, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('250000.0'), 35, 37221, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('315000.0'), 32, 37013, 'ZERO LOT LINE', 'USD'),
#  (2010.0, Decimal('662500.0'), 24, 37215, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 3, 37207, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('34900.0'), 17, 37210, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('71900.0'), 8, 37115, 'SINGLE FAMILY', 'USD '),
#  (2010.0, Decimal('74000.0'), 7, 37115, 'SINGLE FAMILY', 'USD '),
#  (2010.0, Decimal('146000.0'), 11, 37138, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('150000.0'), 14, 37214, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('170000.0'), 27, 37211, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('194500.0'), 33, 37013, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('205500.0'), 32, 37013, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('229000.0'), 4, 37211, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('0.0'), 17, 37204, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 35, 37221, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('0.0'),
 'VACANT RESIDENTIAL LAND', 'USD'),
#  (2010.0, None, 25, 37215, 'VACANT RESIDENTIAL LAND', 'USD'),
#  (2010.0, Decimal('0.0'), 34, 37215, 'VACANT RESIDENTIAL LAND', 'FH'),
#  (2010.0, Decimal('0.0'), 34, 37215, 'SINGLE FAMILY', 'FH'),
#  (2010.0, Decimal('0.0'), 35, 37221, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('0.0'), 5, 37207, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('120000.0'), 8, 37115, 'SINGLE FAMILY', 'USD '),
#  (2010.0, Decimal('199500.0'), 22, 37221, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('205000.0'), 12, 37076, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('223000.0'), 4, 37211, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('252300.0'), 35, 37221, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('0.0'), 34, 37215, 'SINGLE FAMILY', 'FH'),
#  (2010.0, Decimal('0.0'), 23, 37205, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 35, 37221, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('43101.0'), 1, 37218, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('70900.0'), 13, 37214, 'ZERO LOT LINE', 'GSD'),
#  (2010.0, Decimal('78000.0'), 5, 37207, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('121000.0'), 21, 37203, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('162500.0'), 35, 37221, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('210301.0'), 35, 37221, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('262000.0'), 35, 37221, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('0.0'), 27, 37211, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 14, 37076, 'SINGLE FAMILY', 'GSD'),
#  (2010.0, Decimal('0.0'), 20, 37209, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 2, 37208, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('0.0'), 6, 37206, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('19000.0'), 26, 37211, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('24000.0'), 1, 37218, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('35000.0'), 9, 37115, 'SINGLE FAMILY', 'USD '),
#  (2010.0, Decimal('46500.0'), 16, 37211, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('72948.0'), 12, 37076, 'DUPLEX', 'GSD'),
#  (2010.0, Decimal('75000.0'), 2, 37207, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('109850.0'), 7, 37216, 'SINGLE FAMILY', 'USD'),
#  (2010.0, Decimal('125000.0'), 4, 37027, 'RESIDENTIAL CONDO', 'USD'),
#  (2010.0, Decimal('130000.0'), 20, 37209, 'SINGLE FAMILY', 'USD'),
#  ...]

# %%
#Run the sequel query through pandas 

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import statsmodels.api as sm
import pandas as pd
import plotly.express as px 

from IPython.core.display import HTML
# %matplotlib inline

# %%
pd.set_option("display.max_rows", 500)
pd.set_option("display.max_columns", 500)

# %%
price = pd.read_sql(Q1a, con = engine)
price.head()
# Out:
#      year  saleprice  council  propzip             ludesc taxdist
# 0  2010.0        0.0       21    37209      SINGLE FAMILY     USD
# 1  2010.0   395500.0       21    37203  RESIDENTIAL CONDO     USD
# 2  2010.0        0.0       26    37211      SINGLE FAMILY     USD
# 3  2010.0        0.0        5    37207      SINGLE FAMILY     USD
# 4  2010.0    86825.0        9    37115      SINGLE FAMILY     GSD

# %%
price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134318 entries, 0 to 134317
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   year       134318 non-null  float64
#  1   saleprice  116104 non-null  float64
#  2   council    134318 non-null  int64
#  3   propzip    134318 non-null  int64
#  4   ludesc     134318 non-null  object
#  5   taxdist    134318 non-null  object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 6.1+ MB

# %%
price.year.describe()
# Out:
# count    134318.000000
# mean       2016.638567
# std           2.962605
# min        2010.000000
# 25%        2015.000000
# 50%        2017.000000
# 75%        2019.000000
# max        2021.000000
# Name: year, dtype: float64

# %%
#converting to date-time is causing problems on the pivot, so will try converting to numeric
#price['year'] = pd.to_datetime(price['year'], format='%Y')
# to_numeric made it into a float 
#price.year = pd.to_numeric(price.year)
#price['year'] = price['year'].dt.year

#price['year'] = pd.to_datetime(price['year']).dt.year

# %%
#convert saleprice NaNs to 0
price['saleprice'] = price['saleprice'].fillna(0)

# %%
price['saleprice'] = price['saleprice'].apply(int)

# %%
price.head(3)
# Out:
#      year  saleprice  council  propzip             ludesc taxdist
# 0  2010.0          0       21    37209      SINGLE FAMILY     USD
# 1  2010.0     395500       21    37203  RESIDENTIAL CONDO     USD
# 2  2010.0          0       26    37211      SINGLE FAMILY     USD

# %%
ten_yr_price = price[price['year'].isin([2010,2020])]
print(ten_yr_price.head())
# Out:
#      year  saleprice  council  propzip             ludesc taxdist
# 0  2010.0          0       21    37209      SINGLE FAMILY     USD
# 1  2010.0     395500       21    37203  RESIDENTIAL CONDO     USD
# 2  2010.0          0       26    37211      SINGLE FAMILY     USD
# 3  2010.0          0        5    37207      SINGLE FAMILY     USD
# 4  2010.0      86825        9    37115      SINGLE FAMILY     GSD

# %%
ten_yr_pivoted = ten_yr_price.pivot_table(index = ['propzip'], columns = ['year'], values = ['saleprice'], \
                                         aggfunc = {'median', 'mean'})

#.dropna()

# %%
ten_yr_pivoted
# Out:
#              saleprice
#                   mean                   median
# year            2010.0         2020.0    2010.0    2020.0
# propzip
# 37013    105882.824275  237908.371619  117000.0  229000.0
# 37015     37400.000000   54142.857143       0.0       0.0
# 37027    222488.594595  392649.219331  245000.0  375000.0
# 37064    203000.000000  578500.000000  203000.0  578500.0
# 37072     82005.141176  234450.661943   80323.0  249995.0
# 37076    125136.851695  259708.391881  127756.0  260000.0
# 37080    110358.333333  244986.815789  115500.0  262250.0
# 37115     79012.327511  205822.033373   70000.0  200000.0
# 37122    201704.800000  262230.242424  250000.0  365000.0
# 37135    288577.230769  323148.257384  294900.0  330850.0
# 37138    102101.941176  244713.896166   87500.0  238950.0
# 37143     91750.000000  211055.555556   84500.0  215000.0
# 37189    130799.421053  233025.000000  138080.0  226750.0
# 37201    221231.571429  416953.650000  243125.0  339500.0
# 37203    269922.026316  387683.436720  233500.0  377500.0
# 37204    246353.410000  548912.551167  204125.0  475000.0
# 37205    333719.194030  655216.141350  250000.0  449705.0
# 37206    135980.508380  344189.921004  127000.0  380000.0
# 37207     69473.004255  250023.009317   58500.0  240000.0
# 37208     48886.624060  297220.473829   15000.0  310000.0
# 37209    147515.029703  350947.014060  112250.0  350000.0
# 37210     75984.679487  288070.893271   71250.0  245000.0
# 37211    117980.470000  233788.121532  119400.0  259000.0
# 37212    247852.459016  492535.774737  209500.0  418500.0
# 37214     89050.419214  231544.844902   89900.0  242500.0
# 37215    367882.698020  696193.482613  262000.0  580000.0
# 37216    110844.296875  292919.498780  115047.5  321500.0
# 37217     79259.104938  168510.616364   86650.0  185950.0
# 37218     64767.185841  193509.330097   40000.0  179450.0
# 37219    131400.714286  448591.608108  195000.0  362000.0
# 37220    220184.677419  578758.340249  207500.0  460000.0
# 37221    149094.869697  288449.556222  165750.0  305500.0

# %%
ten_yr_pivoted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32 entries, 37013 to 37221
# Data columns (total 4 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   (saleprice, mean, 2010.0)    32 non-null     float64
#  1   (saleprice, mean, 2020.0)    32 non-null     float64
#  2   (saleprice, median, 2010.0)  32 non-null     float64
#  3   (saleprice, median, 2020.0)  32 non-null     float64
# dtypes: float64(4)
# memory usage: 1.2 KB

# %%
#ten_yr_pivoted.columns = ten_yr_pivoted.columns.get_level_values(0)
#ten_yr_pivoted.unstack().reset_index().drop('level_0', axis=1)
# Out:
#     level_1    year  propzip              0
# 0      mean  2010.0    37013  105882.824275
# 1      mean  2010.0    37015   37400.000000
# 2      mean  2010.0    37027  222488.594595
# 3      mean  2010.0    37064  203000.000000
# 37210     75984.679487  288070.893271   71250.0  245000.0
# 37211    117980.470000  233788.121532  119400.0  259000.0
# 37212    247852.459016  492535.774737  209500.0  418500.0
# 37214     89050.419214  231544.844902   89900.0  242500.0
# 37215    367882.698020  696193.482613  262000.0  580000.0
# 37216    110844.296875  292919.498780  115047.5  321500.0
# 37217     79259.104938  168510.616364   86650.0  185950.0
# 37218     64767.185841  193509.330097   40000.0  179450.0
# 37219    131400.714286  448591.608108  195000.0  362000.0
# 37220    220184.677419  578758.340249  207500.0  460000.0
# 37221    149094.869697  288449.556222  165750.0  305500.0

# %%
ten_yr_pivoted['10yr_percent_change'] = 100*(ten_yr_pivoted[2020] - ten_yr_pivoted[2010]) / ten_yr_pivoted[2010]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-c530c427e5a5> in <module>
# ----> 1 ten_yr_pivoted['10yr_percent_change'] = 100*(ten_yr_pivoted.mean[2020] - ten_yr_pivoted.mean[2010]) / ten_yr_pivoted.mean[2010]
#
# TypeError: 'method' object is not subscriptable

# %%
five_yr_price = price[price['year'].isin([2015,2020])]
print(five_yr_price.head())

# %%
five_yr_pivoted = five_yr_price.pivot_table(, columns = ['year'], index = ['propzip'], \
                                            values = ['saleprice'], aggfunc = {'median', 'mean'})

#.dropna()

# %%
five_yr_pivoted.columns = five_yr_pivoted.columns.get_level_values(0)

# %%
five_yr_pivoted['5yr_percent_change'] = 100*(five_yr_pivoted[2020] - five_yr_pivoted[2015]) / five_yr_pivoted[2015]

# %%
five_yr_pivoted.sort_values('percent_change_5', ascending = False).head(5)

# %%
ten_yr_pivoted.sort_values('percent_change_10', ascending = False).head(5)

# %%
#five_yr_pivoted[five_yr_pivoted.percent_change_5].groupby('year').mean().plot()
#plt.title('Mean Sale Price by Zip Code by Year');

# %%
ave_price_2010 = price[price['year']==2010]

# %%
ave_price_2010.groupby('propzip')['saleprice'].mean()

# %%
median_price_2010 = ave_price_2010.groupby('propzip')['saleprice'].median()
median_price_2010

# %%
# med_price_2011 = ave_price_2011.groupby('propzip')['saleprice'].median()
# med_price_2011
median_price_2020 = price[price['year']==2020].groupby('propzip')['saleprice'].median()
median_price_2020

# %%
median_price_2015 = price[price['year']==2015].groupby('propzip')['saleprice'].median()
median_price_2015

# %%
Median_price_trends =

# %%
# price['2011_med_price'] = price[price['year']==2011].groupby('propzip')['saleprice'].median()
# price.head()

# %%
price.info()

# %%
#using merge_ordered because it's ordered/time series data
#comb_med_price_change = pd.merge_ordered(median_price_2011.union, median_price_2016, on='propzip', suffixes('_2011', '_2016').merge_ordered(median_price_2021, on='propzip')

# %%
#median_price_2011 = median_price_2011.to_frame()
# med_price_2016 = pd.Dataframe(median_price_2016)
# med_price_2021 = pd.Dataframe(median_price_2021)

# %%
#index_col = 'propzip'
# comb_med_price_change = median_price_2011.merge(median_price_2016, on = 'propzip', suffixes = ('_2011', '_2016')) \
#                                                 .merge('median_price_2021', on = 'propzip', suffixes = '_2021' )
# comb_med_price_change

# %%
# comb_med_price_change = pd.concat([median_price_2011, median_price_2016, median_price_2021])
# comb_med_price_change

# %%
# Who are the top opioid prescribers? 
# Q2 = '''
# SELECT p.nppes_provider_first_name, p.nppes_provider_last_org_name, 
# SUM(total_claim_count) AS total_claims, d.opioid_drug_flag, p.specialty_description
# FROM prescriber AS p
# INNER JOIN prescription AS p2
# USING (npi)
# INNER JOIN drug AS d
# USING (drug_name)
# WHERE opioid_drug_flag = 'Y'
# GROUP BY p.nppes_provider_first_name, p.nppes_provider_last_org_name, d.opioid_drug_flag, p.specialty_description
# ORDER BY SUM(total_claim_count) DESC;
# '''

# resultQ2 = engine.execute(Q2)

# %%
#resultQ2.fetchall()

# %%
# opioid_prescribers = pd.read_sql(Q2, con = engine)
# opioid_prescribers

# %%
# fips_query = '''
# SELECT *
# FROM fips_county
# LIMIT 10;
# '''

# result_fips = engine.execute(fips_query)

# %%
#result_fips.fetchall()

# %%
# Describe overdose deaths due to opioids in TN from 2015-2018
# Q3 = '''
# SELECT SUM(overdose_deaths) AS overdoses, year, state
# FROM overdose_deaths AS o
# INNER JOIN fips_county AS f
# ON o.fipscounty = f.fipscounty 
# WHERE state = 'TN'
# GROUP BY year, state;
# '''

# resultQ3 = engine.execute(Q3)

# %%
#resultQ3.fetchall()

# %%
# tn_overdoses = pd.read_sql(Q3, con = engine)
# tn_overdoses

# %%
import plotly.express as px

# %%
# fig = px.line(tn_overdoses, x = ['2015', '2016', '2017', '2018'], y='overdoses', 
#               hover_data = ['overdoses'], labels=dict(x="Year", overdoses="Number of Overdose Deaths"))
# fig.update_layout(title = 'Trend for TN Opioid Overdose Deaths, Years 2015-2018')
# fig.show()

# fig.write_html('../sql_rx_project-dankedpat-nationals/data/tn_overdoses.html')

# %%
#resultQ3a.fetchall()

# %%
#1 Which Tennessee counties had a disproportionately high number of opioid prescriptions?
# Q1 = '''
# WITH county AS(
# SELECT npi, nppes_provider_zip5, nppes_provider_state, state, county, f.fipscounty
# FROM prescriber AS p
# JOIN zip_fips AS z
# ON p.nppes_provider_zip5 = z.zip 
# JOIN fips_county AS f
# ON z.fipscounty = f.fipscounty
# ORDER BY county)

# SELECT SUM(total_claim_count) AS rx, opioid_drug_flag, county, state, population
# FROM county as c
# INNER JOIN prescription as p2
# ON c.npi = p2.npi
# INNER JOIN drug AS d
# USING (drug_name)
# INNER JOIN population as p3
# USING (fipscounty)
# WHERE opioid_drug_flag = 'Y' AND state = 'TN'
# GROUP BY county, opioid_drug_flag, state, population
# ORDER BY rx DESC;
# '''

# resultQ1 = engine.execute(Q1)

# %%
# resultQ1.fetchone()

# Q1 = pd.read_sql(Q1, con = engine)
# Q1

# %%
#Q1['Ratio'] = pd.to_numeric((Q1['rx'] / Q1['population']) * 1000)

# %%
# Q1 = Q1.sort_values('Ratio', ascending = False)
# plt.figure(figsize = (15,8))
# Q1['Ratio'].plot(kind = 'bar', color = 'blue', )
# plt.xticks(rotation = 90, fontsize = 10)
# plt.yticks(fontsize = 14)
# plt.xlabel('County', fontsize = 14)
# plt.ylabel('Claims per 1,000 Persons', fontsize = 14)
# plt.title('TN County Opioid Claims per 1,000 Persons', fontsize = 16, fontweight = 'bold');

# %% [markdown]
# gensim for topic modelling, embeddings
#
# https://www.padctn.org/prc/property/63402/card/1
# https://maps.nashville.gov/ParcelViewer/
